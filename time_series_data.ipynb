# %%
#note: http://jonathansoma.com/lede/foundations-2017/classes/working-with-many-files/class/
import glob
import pandas as pd
import numpy as np

# The * is not a regex, it just means "match anything"
# This matches State_County_Penetration_MA_2017_12.csv,State_County_Penetration_MA_2017_09.csv etc.
filenames = glob.glob("./data/time_series/State_County_Penetration_*.csv")

data_types = {'FIPSST': object, 
              'FIPSCNTY': object, 
              'FIPS': object, 
              'SSAST': object, 
              'SSACNTY': object, 
              'SSA': object
             }

#creates a list of dfs, one for each file
list_of_dfs = [pd.read_csv(filename, dtype=data_types, thousands=r',', na_values=["*"]) for filename in filenames]

# zip loops through TWO THINGS AT ONCE
# so you're looking at dataframe #1 and filename #1
# then dataframe #2 and filename #2
# etc
# and assigning that filename as a new column in the dataframe
for dataframe, filename in zip(list_of_dfs, filenames):
    dataframe['filename'] = filename
    
# Combine a list of dataframes, on top of each other
ts_df = pd.concat(list_of_dfs, ignore_index=True)

#creating string date column from filename
ts_df['date'] = ts_df['filename'].apply(lambda x: x.split('Penetration_MA_')[1][0:7])

#create new date+FIPS unique ID
ts_df['d_fips'] = ts_df['date']+'-'+ts_df['FIPS']

#create new datetime column
ts_df['date'] = pd.to_datetime(ts_df['date'], format='%Y_%m')

#new calc for the pop_penetration
ts_df['pop_Penetration'] = ts_df['Enrolled']/ts_df['Eligibles']

#dropping columns we don't need
ts_df.drop(['filename', 'SSAST','SSACNTY','SSA','Penetration'] ,axis = 1, inplace=True)

#cleaning column white space
ts_df = ts_df.rename(columns={'State Name': 'state', 'County Name': 'county'})

# Resetting index so merge is easy
ts_df.set_index('d_fips', inplace = True)

#getting rid of weird non state designation
ts_df = ts_df[ts_df.state != 'Pending State Designation']
ts_df = ts_df[ts_df.county != 'Pending County Designation']

#create new year + FIPS ID for rate info
ts_df['y_fips'] = ts_df['date'].astype('str')
ts_df['y_fips'] = ts_df['y_fips'].str.slice(start=0, stop=4)+'-'+ts_df['FIPS']


ts_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51370 entries, 2014_09-01001 to 2016_03-78030
# Data columns (total 10 columns):
# state              51370 non-null object
# county             51370 non-null object
# FIPSST             51370 non-null object
# FIPSCNTY           51370 non-null object
# FIPS               51370 non-null object
# Eligibles          51370 non-null int64
# Enrolled           49757 non-null float64
# date               51370 non-null datetime64[ns]
# pop_Penetration    49757 non-null float64
# y_fips             51370 non-null object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(6)
# memory usage: 4.3+ MB

# %%
# The * is not a regex, it just means "match anything"
# This matches State_County_Penetration_MA_2017_12.csv,State_County_Penetration_MA_2017_09.csv etc.
filenames = glob.glob("./data/time_series/SCC_Enrollment_MA_*.csv")

data_types = {'FIPS Code': object
             }

#creates a list of dfs, one for each file
list_of_dfs = [pd.read_csv(filename, dtype=data_types, thousands=r',', na_values=["*"]) for filename in filenames]

# zip loops through TWO THINGS AT ONCE
# so you're looking at dataframe #1 and filename #1
# then dataframe #2 and filename #2
# etc
# and assigning that filename as a new column in the dataframe
for dataframe, filename in zip(list_of_dfs, filenames):
    dataframe['filename'] = filename
    
# Combine a list of dataframes, on top of each other
plan_enroll_df = pd.concat(list_of_dfs, ignore_index=True)

#creating string date column from filename
plan_enroll_df['date'] = plan_enroll_df['filename'].apply(lambda x: x.split('SCC_Enrollment_MA_')[1][0:7])

#create new date+FIPS unique ID
plan_enroll_df['d_fips'] = plan_enroll_df['date']+'-'+plan_enroll_df['FIPS Code']

#make sure col names aren't confusing after merge
plan_enroll_df.rename(columns={'Enrolled':'plan_Enrolled'}, inplace=True)


#creates df with 6,081,762 rows

# %%
plan_enroll_df.head(50)
# Out:
#      County State Contract ID  \
# 0   Autauga    AL       H0104
# 1   Autauga    AL       H0107
# 2   Autauga    AL       H0150
# 3   Autauga    AL       H0151
# 4   Autauga    AL       H0154
# 5   Autauga    AL       H0504
# 6   Autauga    AL       H0523
# 7   Autauga    AL       H0524
# 8   Autauga    AL       H0710
# 9   Autauga    AL       H1016
# 10  Autauga    AL       H1109
# 11  Autauga    AL       H1304
# 12  Autauga    AL       H1365
# 13  Autauga    AL       H1417
# 14  Autauga    AL       H1463
# 15  Autauga    AL       H1517
# 16  Autauga    AL       H1537
# 17  Autauga    AL       H1607
# 18  Autauga    AL       H1608
# 19  Autauga    AL       H1609
# 20  Autauga    AL       H1666
# 21  Autauga    AL       H1692
# 22  Autauga    AL       H1737
# 23  Autauga    AL       H1961
# 24  Autauga    AL       H2001
# 25  Autauga    AL       H2165
# 26  Autauga    AL       H2171
# 27  Autauga    AL       H2228
# 28  Autauga    AL       H2230
# 29  Autauga    AL       H2320
# 30  Autauga    AL       H2354
# 31  Autauga    AL       H2406
# 32  Autauga    AL       H2591
# 33  Autauga    AL       H2663
# 34  Autauga    AL       H2667
# 35  Autauga    AL       H2672
# 36  Autauga    AL       H2701
# 37  Autauga    AL       H2775
# 38  Autauga    AL       H2816
# 39  Autauga    AL       H2836
# 40  Autauga    AL       H3152
# 41  Autauga    AL       H3154
# 42  Autauga    AL       H3312
# 43  Autauga    AL       H3335
# 44  Autauga    AL       H3342
# 45  Autauga    AL       H3344
# 46  Autauga    AL       H3359
# 47  Autauga    AL       H3362
# 48  Autauga    AL       H3404
# 49  Autauga    AL       H3471
#
#                                     Organization Name Organization Type  \
# 0               BLUE CROSS AND BLUE SHIELD OF ALABAMA         Local CCP
# 1                     HEALTH CARE SERVICE CORPORATION         Local CCP
# 2                       HEALTHSPRING OF ALABAMA, INC.         Local CCP
# 3                   UNITEDHEALTHCARE OF ALABAMA, INC.         Local CCP
# 4                                   VIVA HEALTH, INC.         Local CCP
# 5                      CALIFORNIA PHYSICIANS' SERVICE         Local CCP
# 6                     AETNA HEALTH OF CALIFORNIA INC.         Local CCP
# 7                          KAISER FOUNDATION HP, INC.         Local CCP
# 8                  UNITEDHEALTHCARE INSURANCE COMPANY         Local CCP
# 9                                         AVMED, INC.         Local CCP
# 10                              AETNA HEALTH INC.(GA)         Local CCP
# 11                       REGENCE BLUE SHIELD OF IDAHO         Local CCP
# 12         MARTIN'S POINT GENERATIONS ADVANTAGE, INC.         Local CCP
# 13                      HEALTH ALLIANCE CONNECT, INC.         Local CCP
# 14                      HEALTH ALLIANCE CONNECT, INC.         Local CCP
# 15                   ANTHEM INSURANCE COMPANIES, INC.         Local CCP
# 16     UNITEDHEALTHCARE INSURANCE COMPANY OF NEW YORK         Local CCP
# 17                   ANTHEM INSURANCE COMPANIES, INC.         Local CCP
# 18         COVENTRY HEALTH AND LIFE INSURANCE COMPANY         Local CCP
# 19                               AETNA HEALTH OF IOWA         Local CCP
# 20                    HCSC INSURANCE SERVICES COMPANY         Local CCP
# 21        COVENTRY HEALTH CARE OF WEST VIRGINIA, INC.         Local CCP
# 22                    HEALTH ALLIANCE - MIDWEST, INC.         Local CCP
# 23                               PEOPLES HEALTH, INC.         Local CCP
# 24     SIERRA HEALTH AND LIFE INSURANCE COMPANY, INC.         Local CCP
# 25  HEALTHSPRING LIFE & HEALTH INSURANCE COMPANY, ...         Local CCP
# 26               CARE N' CARE INSURANCE COMPANY, INC.         Local CCP
# 27                 UNITEDHEALTHCARE INSURANCE COMPANY         Local CCP
# 28              BCBS  OF MASSACHUSETTS HMO BLUE, INC.         Local CCP
# 29                                    PRIORITY HEALTH         Local CCP
# 30                   HEALTH ALLIANCE PLAN OF MICHIGAN         Local CCP
# 31     SIERRA HEALTH AND LIFE INSURANCE COMPANY, INC.         Local CCP
# 32                    HEALTH ALLIANCE - MIDWEST, INC.         Local CCP
# 33              COVENTRY HEALTH CARE OF MISSOURI, INC         Local CCP
# 34              COVENTRY HEALTH CARE OF MISSOURI, INC         Local CCP
# 35               COVENTRY HEALTH CARE OF KANSAS, INC.         Local CCP
# 36                           NEW WEST HEALTH SERVICES         Local CCP
# 37  AMERICAN PROGRESSIVE LIFE & HLTH INS COMPANY O...         Local CCP
# 38  AMERICAN PROGRESSIVE LIFE & HLTH INS COMPANY O...              PFFS
# 39                          ANTHEM HEALTH PLANS, INC.         Local CCP
# 40                             AETNA HEALTH INC. (NJ)         Local CCP
# 41                          HORIZON INSURANCE COMPANY         Local CCP
# 42                             AETNA HEALTH INC. (NY)         Local CCP
# 43                         EXCELLUS HEALTH PLAN, INC.         Local CCP
# 44                EMPIRE HEALTHCHOICE ASSURANCE, INC.         Local CCP
# 45            INDEPENDENT HEALTH BENEFITS CORPORATION         Local CCP
# 46                      HEALTHFIRST HEALTH PLAN, INC.         Local CCP
# 47               INDEPENDENT HEALTH ASSOCIATION, INC.         Local CCP
# 48       BLUE CROSS AND BLUE SHIELD OF NORTH CAROLINA         Local CCP
# 49        HEALTH ALLIANCE NORTHWEST HEALTH PLAN, INC.         Local CCP
#
#      Plan Type  SSA Code FIPS Code  plan_Enrolled  \
# 0    Local PPO      1000     01001          361.0
# 1    Local PPO      1000     01001            NaN
# 2   HMO/HMOPOS      1000     01001          732.0
# 3   HMO/HMOPOS      1000     01001          666.0
# 4   HMO/HMOPOS      1000     01001         1290.0
# 5   HMO/HMOPOS      1000     01001            NaN
# 6   HMO/HMOPOS      1000     01001            NaN
# 7   HMO/HMOPOS      1000     01001            NaN
# 8    Local PPO      1000     01001            NaN
# 9   HMO/HMOPOS      1000     01001            NaN
# 10  HMO/HMOPOS      1000     01001            NaN
# 11   Local PPO      1000     01001            NaN
# 12   Local PPO      1000     01001            NaN
# 13   Local PPO      1000     01001            NaN
# 14  HMO/HMOPOS      1000     01001            NaN
# 15   Local PPO      1000     01001            NaN
# 16   Local PPO      1000     01001            NaN
# 17   Local PPO      1000     01001            NaN
# 18   Local PPO      1000     01001            NaN
# 19  HMO/HMOPOS      1000     01001            NaN
# 20   Local PPO      1000     01001            NaN
# 21  HMO/HMOPOS      1000     01001            NaN
# 22  HMO/HMOPOS      1000     01001            NaN
# 23  HMO/HMOPOS      1000     01001            NaN
# 24   Local PPO      1000     01001           39.0
# 25  HMO/HMOPOS      1000     01001            NaN
# 26  HMO/HMOPOS      1000     01001            NaN
# 27   Local PPO      1000     01001            NaN
# 28   Local PPO      1000     01001            NaN
# 29  HMO/HMOPOS      1000     01001            NaN
# 30  HMO/HMOPOS      1000     01001            NaN
# 31   Local PPO      1000     01001            NaN
# 32   Local PPO      1000     01001            NaN
# 33  HMO/HMOPOS      1000     01001            NaN
# 34  HMO/HMOPOS      1000     01001            NaN
# 35  HMO/HMOPOS      1000     01001            NaN
# 36   Local PPO      1000     01001            NaN
# 37   Local PPO      1000     01001            NaN
# 38        PFFS      1000     01001            NaN
# 39   Local PPO      1000     01001            NaN
# 40  HMO/HMOPOS      1000     01001            NaN
# 41  HMO/HMOPOS      1000     01001            NaN
# 42  HMO/HMOPOS      1000     01001            NaN
# 43   Local PPO      1000     01001            NaN
# 44   Local PPO      1000     01001            NaN
# 45   Local PPO      1000     01001            NaN
# 46  HMO/HMOPOS      1000     01001            NaN
# 47  HMO/HMOPOS      1000     01001            NaN
# 48   Local PPO      1000     01001            NaN
# 49  HMO/HMOPOS      1000     01001            NaN
#
#                                             filename     date         d_fips
# 0   ./data/time_series/SCC_Enrollment_MA_2016_06.csv  2016_06  2016_06-01001
# 1   ./data/time_series/SCC_Enrollment_MA_2016_06.csv  2016_06  2016_06-01001
# 2   ./data/time_series/SCC_Enrollment_MA_2016_06.csv  2016_06  2016_06-01001
# 3   ./data/time_series/SCC_Enrollment_MA_2016_06.csv  2016_06  2016_06-01001
# 4   ./data/time_series/SCC_Enrollment_MA_2016_06.csv  2016_06  2016_06-01001
# 5   ./data/time_series/SCC_Enrollment_MA_2016_06.csv  2016_06  2016_06-01001
# 6   ./data/time_series/SCC_Enrollment_MA_2016_06.csv  2016_06  2016_06-01001
# 7   ./data/time_series/SCC_Enrollment_MA_2016_06.csv  2016_06  2016_06-01001
# 8   ./data/time_series/SCC_Enrollment_MA_2016_06.csv  2016_06  2016_06-01001
# 9   ./data/time_series/SCC_Enrollment_MA_2016_06.csv  2016_06  2016_06-01001
# 10  ./data/time_series/SCC_Enrollment_MA_2016_06.csv  2016_06  2016_06-01001
# 11  ./data/time_series/SCC_Enrollment_MA_2016_06.csv  2016_06  2016_06-01001
# 12  ./data/time_series/SCC_Enrollment_MA_2016_06.csv  2016_06  2016_06-01001
# 13  ./data/time_series/SCC_Enrollment_MA_2016_06.csv  2016_06  2016_06-01001
# 14  ./data/time_series/SCC_Enrollment_MA_2016_06.csv  2016_06  2016_06-01001
# 15  ./data/time_series/SCC_Enrollment_MA_2016_06.csv  2016_06  2016_06-01001
# 16  ./data/time_series/SCC_Enrollment_MA_2016_06.csv  2016_06  2016_06-01001
# 17  ./data/time_series/SCC_Enrollment_MA_2016_06.csv  2016_06  2016_06-01001
# 18  ./data/time_series/SCC_Enrollment_MA_2016_06.csv  2016_06  2016_06-01001
# 19  ./data/time_series/SCC_Enrollment_MA_2016_06.csv  2016_06  2016_06-01001
# 20  ./data/time_series/SCC_Enrollment_MA_2016_06.csv  2016_06  2016_06-01001
# 21  ./data/time_series/SCC_Enrollment_MA_2016_06.csv  2016_06  2016_06-01001
# 22  ./data/time_series/SCC_Enrollment_MA_2016_06.csv  2016_06  2016_06-01001
# 23  ./data/time_series/SCC_Enrollment_MA_2016_06.csv  2016_06  2016_06-01001
# 24  ./data/time_series/SCC_Enrollment_MA_2016_06.csv  2016_06  2016_06-01001
# 25  ./data/time_series/SCC_Enrollment_MA_2016_06.csv  2016_06  2016_06-01001
# 26  ./data/time_series/SCC_Enrollment_MA_2016_06.csv  2016_06  2016_06-01001
# 27  ./data/time_series/SCC_Enrollment_MA_2016_06.csv  2016_06  2016_06-01001
# 28  ./data/time_series/SCC_Enrollment_MA_2016_06.csv  2016_06  2016_06-01001
# 29  ./data/time_series/SCC_Enrollment_MA_2016_06.csv  2016_06  2016_06-01001
# 30  ./data/time_series/SCC_Enrollment_MA_2016_06.csv  2016_06  2016_06-01001
# 31  ./data/time_series/SCC_Enrollment_MA_2016_06.csv  2016_06  2016_06-01001
# 32  ./data/time_series/SCC_Enrollment_MA_2016_06.csv  2016_06  2016_06-01001
# 33  ./data/time_series/SCC_Enrollment_MA_2016_06.csv  2016_06  2016_06-01001
# 34  ./data/time_series/SCC_Enrollment_MA_2016_06.csv  2016_06  2016_06-01001
# 35  ./data/time_series/SCC_Enrollment_MA_2016_06.csv  2016_06  2016_06-01001
# 36  ./data/time_series/SCC_Enrollment_MA_2016_06.csv  2016_06  2016_06-01001
# 37  ./data/time_series/SCC_Enrollment_MA_2016_06.csv  2016_06  2016_06-01001
# 38  ./data/time_series/SCC_Enrollment_MA_2016_06.csv  2016_06  2016_06-01001
# 39  ./data/time_series/SCC_Enrollment_MA_2016_06.csv  2016_06  2016_06-01001
# 40  ./data/time_series/SCC_Enrollment_MA_2016_06.csv  2016_06  2016_06-01001
# 41  ./data/time_series/SCC_Enrollment_MA_2016_06.csv  2016_06  2016_06-01001
# 42  ./data/time_series/SCC_Enrollment_MA_2016_06.csv  2016_06  2016_06-01001
# 43  ./data/time_series/SCC_Enrollment_MA_2016_06.csv  2016_06  2016_06-01001
# 44  ./data/time_series/SCC_Enrollment_MA_2016_06.csv  2016_06  2016_06-01001
# 45  ./data/time_series/SCC_Enrollment_MA_2016_06.csv  2016_06  2016_06-01001
# 46  ./data/time_series/SCC_Enrollment_MA_2016_06.csv  2016_06  2016_06-01001
# 47  ./data/time_series/SCC_Enrollment_MA_2016_06.csv  2016_06  2016_06-01001
# 48  ./data/time_series/SCC_Enrollment_MA_2016_06.csv  2016_06  2016_06-01001
# 49  ./data/time_series/SCC_Enrollment_MA_2016_06.csv  2016_06  2016_06-01001

# %%
#function for calculating the HHI index for each county/date.  https://www.investopedia.com/terms/h/hhi.asp
def hhi(df):
    temp_df = pd.DataFrame(df[df['plan_Enrolled'] > 0].groupby(['d_fips','Organization Name'])['plan_Enrolled'].sum())
    temp_df.reset_index(inplace = True)
    temp_df.set_index('d_fips', inplace = True)
    temp2 = temp_df.join(ts_df['Enrolled'], how='left')
    temp2['plan_mkt_share'] = temp2['plan_Enrolled'] / temp2['Enrolled']
    temp2['sq_mkt_share'] = (temp2['plan_mkt_share']*100)**2
    temp3 = pd.DataFrame(temp2.groupby('d_fips')['sq_mkt_share'].sum())
    temp3.rename(columns={'sq_mkt_share':'HHI_Index'}, inplace=True)
    return temp3

hhi_df = hhi(plan_enroll_df)

# %%
#need to get a crosswalk to change between  SSA and FIPS
data_types = {'SSA State county code': object,
              'FIPS State county code': object  
             }

crosswalk = pd.read_excel('./data/time_series/CBSAtoCountycrosswalk_FY15_FR.xlsx', dtype=data_types)
crosswalk = crosswalk[['SSA State county code', 'FIPS State county code']]
crosswalk.columns=['SSA', 'FIPS']
crosswalk.head()
# Out:
#      SSA   FIPS
# 0  01000  01001
# 1  01010  01003
# 2  01020  01005
# 3  01030  01007
# 4  01040  01009

# %%
# Building payment rate dfs.  Note, there is no data from 2014

#2015
df15 = pd.read_csv("./data/time_series/CountyRate2015.csv", dtype=data_types, thousands=r',', na_values=["*"], skiprows=2)
df15 = df15.merge(crosswalk, how='left', left_on='Code', right_on='SSA')
df15 = df15[['FIPS', ' 5% Bonus 2015 Rate', ' 3.5% Bonus 2015 Rate', ' 0% Bonus 2015 Rate']]
df15.columns=['FIPS', "5_pct_bonus", "3.5_pct_bonus", "0_pct_bonus"]
df15['y_fips'] = '2015'+ '-' + df15['FIPS'] 

#2016
# note, for some reason, they did not change the year in the headers for this csv
df16 = pd.read_csv("./data/time_series/CountyRate2016.csv", dtype=data_types, thousands=r',', na_values=["*"], skiprows=3)
df16 = df16.merge(crosswalk, how='left', left_on='Code', right_on='SSA')
df16 = df16[['FIPS', ' 5% Bonus 2015 Rate', '3.5% Bonus 2015 Rate', ' 0% Bonus 2015 Rate']]
df16.columns=['FIPS', "5_pct_bonus", "3.5_pct_bonus", "0_pct_bonus"]
df16['y_fips'] = '2016'+ '-' + df16['FIPS'] 

#2017
df17 = pd.read_csv("./data/time_series/CountyRate2017.csv", dtype=data_types, thousands=r',', na_values=["*"], skiprows=1)
df17 = df17.merge(crosswalk, how='left', left_on='Code', right_on='SSA')
df17 = df17[['FIPS', 'Parts A&B  5% Bonus 2017 Rate', 'Parts A&B  3% Bonus 2017 Rate', 'Parts A&B  0% Bonus 2017 Rate']]
df17.columns=['FIPS', "5_pct_bonus", "3.5_pct_bonus", "0_pct_bonus"]
df17['y_fips'] = '2017'+ '-' + df17['FIPS'] 

# Combine a list of dataframes, on top of each other
rate_df = pd.concat([df15, df16, df17], ignore_index=True)

rate_df.head()
# Out:
#     FIPS  5_pct_bonus  3.5_pct_bonus  0_pct_bonus      y_fips
# 0  01001       781.67         760.35       710.61  2015-01001
# 1  01003       793.71         772.78       723.94  2015-01003
# 2  01005       782.79         782.79       760.28  2015-01005
# 3  01007       801.48         787.29       754.18  2015-01007
# 4  01009       797.12         775.38       724.65  2015-01009

# %%
# join hhi_df to main ts_df
ts_df = ts_df.join(hhi_df, how='left')

ts_df.head()
# Out:
#                  state   county FIPSST FIPSCNTY   FIPS  Eligibles  Enrolled  \
# d_fips
# 2014_09-01001  Alabama  Autauga     01      001  01001       9612    3049.0
# 2014_09-01003  Alabama  Baldwin     01      003  01003      42730   13573.0
# 2014_09-01005  Alabama  Barbour     01      005  01005       6097     896.0
# 2014_09-01007  Alabama     Bibb     01      007  01007       4647    1690.0
# 2014_09-01009  Alabama   Blount     01      009  01009      11385    4719.0
#
#                     date  pop_Penetration      y_fips    HHI_Index
# d_fips
# 2014_09-01001 2014-09-01         0.317208  2014-01001  2494.719193
# 2014_09-01003 2014-09-01         0.317646  2014-01003  2061.361924
# 2014_09-01005 2014-09-01         0.146958  2014-01005  5958.114935
# 2014_09-01007 2014-09-01         0.363675  2014-01007  2950.456917
# 2014_09-01009 2014-09-01         0.414493  2014-01009  3086.813525

# %%
# Join rate info to main ts_df 
ts_df = ts_df.merge(rate_df, how='left')
ts_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51382 entries, 0 to 51381
# Data columns (total 14 columns):
# state              51382 non-null object
# county             51382 non-null object
# FIPSST             51382 non-null object
# FIPSCNTY           51382 non-null object
# FIPS               51382 non-null object
# Eligibles          51382 non-null int64
# Enrolled           49769 non-null float64
# date               51382 non-null datetime64[ns]
# pop_Penetration    49769 non-null float64
# y_fips             51382 non-null object
# HHI_Index          48867 non-null float64
# 5_pct_bonus        38422 non-null float64
# 3.5_pct_bonus      38422 non-null float64
# 0_pct_bonus        38422 non-null float64
# dtypes: datetime64[ns](1), float64(6), int64(1), object(6)
# memory usage: 5.9+ MB

# %%
# ts_df.to_csv('MA_time_series_by_county.csv', index=False)
ts_df.head()
# Out:
#      state   county FIPSST FIPSCNTY   FIPS  Eligibles  Enrolled       date  \
# 0  Alabama  Autauga     01      001  01001       9612    3049.0 2014-09-01
# 1  Alabama  Baldwin     01      003  01003      42730   13573.0 2014-09-01
# 2  Alabama  Barbour     01      005  01005       6097     896.0 2014-09-01
# 3  Alabama     Bibb     01      007  01007       4647    1690.0 2014-09-01
# 4  Alabama   Blount     01      009  01009      11385    4719.0 2014-09-01
#
#    pop_Penetration      y_fips    HHI_Index  5_pct_bonus  3.5_pct_bonus  \
# 0         0.317208  2014-01001  2494.719193          NaN            NaN
# 1         0.317646  2014-01003  2061.361924          NaN            NaN
# 2         0.146958  2014-01005  5958.114935          NaN            NaN
# 3         0.363675  2014-01007  2950.456917          NaN            NaN
# 4         0.414493  2014-01009  3086.813525          NaN            NaN
#
#    0_pct_bonus
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
